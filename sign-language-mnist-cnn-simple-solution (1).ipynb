# %% [markdown]
# # <p style="background-color: black; color: lightblue; padding-right: 100vw; text-align: center; font-family:newtimeroman;padding: 10px; border-radius: 15px 50px; border: 2px solid lightblue;font-size: 33px; text-shadow: 2px 2px 5px rgba(4, 5, 0, 0.5); box-shadow: 5px 5px 15px white;"><span style="color: #e67e22; margin: 0 10px; animation: flicker 1s infinite;">🍂</span> Sign Language Detection ||  ASL || CNN || Simple Solution ||  Fully Explained  🍃

# %% [markdown]
# ***Sign languages are like spoken languages, but instead of using sounds, they use hand movements, facial expressions, and body gestures to communicate. Just like how English or Spanish have their own rules and words, sign languages have their own too.***

# %% [markdown]
# <div style="max-width: 800px; margin: 40px auto; padding: 20px; border-radius: 15px; background-color: #0f1e2d; color: #c0c0c0; font-family: 'Roboto', sans-serif; position: relative; overflow: hidden; box-shadow: 0 4px 15px rgba(0, 0, 0, 0.3);">
#   <div style="display: flex; align-items: center; justify-content: space-between;">
#     <div style="max-width: 60%;">
#       <h1 style="font-size: 32px; font-weight: 700; margin: 0; color: #66cccc;">Hello, It's Me</h1>
#       <h2 style="font-size: 28px; font-weight: 700; margin: 10px 0; color: #66cccc;">M. Ibrahim Qasmi </h2>
#       <h3 style="font-size: 22px; font-weight: 400; color: #99cccc; margin: 10px 0;">And I'm a <span style="font-weight: 700;">Data Analyst</span></h3>
#       <p style="font-size: 16px; line-height: 1.6; color: #a0a0a0;">
#       As a fervent data analyst, I am deeply engaged in exploring the intricate domain of machine learning.
#       </p>
#       <div style="display: flex; gap: 15px; margin: 20px 0;">
#         <a href="https://www.facebook.com/profile.php?id=100010324487471" target="_blank" style="text-decoration: none;">
#           <img src="https://cdn-icons-png.flaticon.com/512/733/733547.png" alt="Facebook" style="width: 24px; height: 24px;">
#         </a>
#         <a href="https://www.kaggle.com/muhammadibrahimqasmi" target="_blank" style="text-decoration: none;">
#           <img src="https://cdn4.iconfinder.com/data/icons/logos-and-brands/512/189_Kaggle_logo_logos-512.png" alt="Kaggle" style="width: 24px; height: 24px;">
#         </a>
#         <a href="https://github.com/muhammadibrahim313" target="_blank" style="text-decoration: none;">
#           <img src="https://cdn-icons-png.flaticon.com/512/25/25657.png" alt="GitHub" style="width: 24px; height: 24px;">
#         </a>
#         <a href="https://www.linkedin.com/in/muhammad-ibrahim-qasmi-9876a1297/" target="_blank" style="text-decoration: none;">
#           <img src="https://cdn-icons-png.flaticon.com/512/174/174857.png" alt="LinkedIn" style="width: 24px; height: 24px;">
#         </a>
#       </div>
#       <a href="https://www.kaggle.com/muhammadibrahimqasmi/code" style="display: inline-block; padding: 10px 20px; border-radius: 5px; background-color: #66cccc; color: #0f1e2d; text-decoration: none; font-weight: 700; margin-top: 10px;">
#         Inspect recent contributions
#       </a>
#     </div>
#     <div style="max-width: 35%; position: relative;">
#       <div style="border-radius: 15px; overflow: hidden; box-shadow: 0 0 20px rgba(0, 230, 230, 0.7); background-color: #66cccc; padding: 10px;">
#         <img src="https://media.licdn.com/dms/image/D4D03AQHoY6n7XXJ_lQ/profile-displayphoto-shrink_400_400/0/1715361232180?e=1721260800&v=beta&t=owqH4rNF1ylNNfdnznwTvxOXmVGmt3I3X8yVm10cGww" alt="Profile Picture" style="width: 100%; height: auto; border-radius: 15px;">
#       </div>
#     </div>
#   </div>
# </div>

# %% [markdown]
# <a href="https://ars.els-cdn.com/content/image/1-s2.0-B9780128233849000190-f20-01-9780128233849.jpg" style="display: block; text-align: center; border: 4px solid lightblue;box-shadow: 5px 5px 15px white;">
#     <img src="https://ars.els-cdn.com/content/image/1-s2.0-B9780128233849000190-f20-01-9780128233849.jpg" alt="image" />
# </a>

# %% [markdown]
# # <p style="background-color: black; color: lightblue; padding-right: 100vw; text-align: center; font-family:newtimeroman;padding: 10px; border-radius: 15px 50px; border: 2px solid lightblue;font-size: 33px; text-shadow: 2px 2px 5px rgba(4, 5, 0, 0.5); box-shadow: 5px 5px 15px white;"><span style="color: #e67e22; margin: 0 10px; animation: flicker 1s infinite;">🍂</span> Problem Statement  🍃

# %% [markdown]
# ***We have a bunch of images representing different ASL gestures. Each image is like a tiny grayscale picture, 28 pixels by 28 pixels in size. We split our data into two CSV files. In each row of these files, the first thing we see is the letter that the gesture represents, like 'A', 'B', 'C', and so on. After that, we have 784 numbers representing the darkness of each pixel in the image.***

# %% [markdown]
# # <p style="background-color: black; color: lightblue; padding-right: 100vw; text-align: center; font-family:newtimeroman;padding: 10px; border-radius: 15px 50px; border: 2px solid lightblue;font-size: 33px; text-shadow: 2px 2px 5px rgba(4, 5, 0, 0.5); box-shadow: 5px 5px 15px white;"><span style="color: #e67e22; margin: 0 10px; animation: flicker 1s infinite;">🍂</span> About Dataset  🍃

# %% [markdown]
# - We have two CSV files, each with a bunch of rows.
# - The first column in each row tells us which letter the image is representing.
# - The other 784 columns give us the grayscale values of each pixel in the image.
# - There are 24 different letters we're dealing with, from 'A' to 'I' and 'K' to 'Y'.

# %% [markdown]
# # <p style="background-color: black; color: lightblue; padding-right: 100vw; text-align: center; font-family:newtimeroman;padding: 10px; border-radius: 15px 50px; border: 2px solid lightblue;font-size: 33px; text-shadow: 2px 2px 5px rgba(4, 5, 0, 0.5); box-shadow: 5px 5px 15px white;"><span style="color: #e67e22; margin: 0 10px; animation: flicker 1s infinite;">🍂</span> My Aim  🍃

# %% [markdown]
# ***My goal is to utilize CNNs in the most straightforward manner possible, guiding through each step from inception to completion with ease.***

# %% [markdown]
# ---

# %% [markdown]
# # <p style="background-color: black; color: lightblue; padding-right: 100vw; text-align: center; font-family:newtimeroman;padding: 10px; border-radius: 15px 50px; border: 2px solid lightblue;font-size: 33px; text-shadow: 2px 2px 5px rgba(4, 5, 0, 0.5); box-shadow: 5px 5px 15px white;"><span style="color: #e67e22; margin: 0 10px; animation: flicker 1s infinite;">🍂</span> Import Modules  🍃

# %%
# Importing necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random
import tensorflow as tf
import tensorflow_hub as hub
from PIL import Image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os
import zipfile
import cv2
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.layers import Dense, Conv2D, Dropout, Flatten, MaxPooling2D, BatchNormalization
from sklearn.preprocessing import LabelBinarizer
import plotly.express as px
from kerastuner import RandomSearch
from kerastuner.engine.hyperparameters import HyperParameters
from tensorflow.keras.callbacks import ReduceLROnPlateau
from keras.models import Sequential, Model
from keras.layers import Conv2D
from tensorflow.keras import datasets, layers, models

# Tensorflow CUDA warnings will not be shown here 
import warnings
warnings.filterwarnings('ignore')
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

print("TensorFlow version is:", tf.__version__)
# pre defiend seed and rand,
seed = 42
np.random.seed =seed

# Class for colored print statements
class color:
    """
    Sets colors for printouts.
    """
    GREEN = '\033[92m'
    YELLOW = '\033[93m'
    RED = '\033[91m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'
    END = '\033[0m'

# Printouts color scheme
g_, y_, r_ = color.GREEN, color.YELLOW, color.RED
bd_, un_, end_ = color.BOLD, color.UNDERLINE, color.END
yb_, gb_  = bd_+y_, bd_+g_
gbu_ = gb_+un_
cmap_ = ['#007427', '#B27D12']

print(f'{yb_}\n[INFO] Lets Go.{end_}')
# Out:
# TensorFlow version is: 2.15.0
#
# [INFO] Lets Go.

# %% [markdown]
# # <p style="background-color: black; color: lightblue; padding-right: 100vw; text-align: center; font-family:newtimeroman;padding: 10px; border-radius: 15px 50px; border: 2px solid lightblue;font-size: 33px; text-shadow: 2px 2px 5px rgba(4, 5, 0, 0.5); box-shadow: 5px 5px 15px white;"><span style="color: #e67e22; margin: 0 10px; animation: flicker 1s infinite;">🍂</span> Import Dataset  🍃

# %% [markdown]
# <span style="font-family:cursive; font-size:36px; padding:8px 16px; border-radius:98px 40px 160px 8px; border-left:8px solid lightblue ; font-weight:bold;"> 1 <span style="color:lighblue ; font-style: italic;">Reading Dataset </span>

# %%
#loading data
train = pd.read_csv("../input/sign-language-mnist/sign_mnist_train/sign_mnist_train.csv")
test = pd.read_csv("../input/sign-language-mnist/sign_mnist_test/sign_mnist_test.csv")

print(f'{yb_}\n=============================\n    Test and Train Data\n   has been successfully\n          loaded!\n============================={end_}')
# Out:
# ...
#     Test and Train Data
#    has been successfully
#           loaded!
# ...

# %% [markdown]
# <span style="font-family:cursive; font-size:36px; padding:8px 16px; border-radius:98px 40px 160px 8px; border-left:8px solid lightblue ; font-weight:bold;"> 2 <span style="color:lighblue ; font-style: italic;">Train dataset head </span>

# %%
train.head()
# Out:
#    label  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  \
# 0      3     107     118     127     134     139     143     146     150
# 1      6     155     157     156     156     156     157     156     158
# 2      2     187     188     188     187     187     186     187     188
# 3      2     211     211     212     212     211     210     211     210
# 4     13     164     167     170     172     176     179     180     184
#
#    pixel9  ...  pixel775  pixel776  pixel777  pixel778  pixel779  pixel780  \
# 0     153  ...       207       207       207       207       206       206
# 1     158  ...        69       149       128        87        94       163
# 2     187  ...       202       201       200       199       198       199
# 3     210  ...       235       234       233       231       230       226
# 4     185  ...        92       105       105       108       133       163
#
#    pixel781  pixel782  pixel783  pixel784
# ...

# %% [markdown]
# <span style="font-family:cursive; font-size:36px; padding:8px 16px; border-radius:98px 40px 160px 8px; border-left:8px solid lightblue ; font-weight:bold;"> 3 <span style="color:lighblue ; font-style: italic;">Test dataset head </span>

# %%
test.head()
# Out:
#    label  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  \
# 0      6     149     149     150     150     150     151     151     150
# 1      5     126     128     131     132     133     134     135     135
# 2     10      85      88      92      96     105     123     135     143
# 3      0     203     205     207     206     207     209     210     209
# 4      3     188     191     193     195     199     201     202     203
#
#    pixel9  ...  pixel775  pixel776  pixel777  pixel778  pixel779  pixel780  \
# 0     151  ...       138       148       127        89        82        96
# 1     136  ...        47       104       194       183       186       184
# 2     147  ...        68       166       242       227       230       227
# 3     210  ...       154       248       247       248       253       236
# 4     203  ...        26        40        64        48        29        46
#
#    pixel781  pixel782  pixel783  pixel784
# ...

# %% [markdown]
# <span style="font-family:cursive; font-size:36px; padding:8px 16px; border-radius:98px 40px 160px 8px; border-left:8px solid lightblue ; font-weight:bold;"> 4 <span style="color:lighblue ; font-style: italic;">Shape of dataset </span>

# %%
print(f"{yb_}\n{'='*30}\n    Shape of Training Dataset\n{'='*30}\n{train.shape}\n")
print(f"{yb_}\n{'='*30}\n    Shape of Testing Dataset\n{'='*30}\n{test.shape}{end_}")
# Out:
# ...
#     Shape of Training Dataset
# ...
# (27455, 785)
#
#
# ...
#     Shape of Testing Dataset
# ...
# (7172, 785)

# %% [markdown]
# <span style="font-family:cursive; font-size:36px; padding:8px 16px; border-radius:98px 40px 160px 8px; border-left:8px solid lightblue ; font-weight:bold;"> 5 <span style="color:lighblue ; font-style: italic;">Null Values </span>

# %%
#from training data 
cols =train.columns
colours = ['#747BA1', '#FFBA77'] 
sns.heatmap(train[cols].isnull(), cmap=sns.color_palette(colours))
# Out:
# <Axes: >

# %%
# from testing data 
cols =test.columns
colours = ['#747BA1', '#FFBA77'] # specify the orange  - yellow is missing. blue is not missing.
sns.heatmap(test[cols].isnull(), cmap=sns.color_palette(colours))
# Out:
# <Axes: >

# %% [markdown]
# <span style="font-family:cursive; font-size:36px; padding:8px 16px; border-radius:98px 40px 160px 8px; border-left:8px solid lightblue ; font-weight:bold;"> 6 <span style="color:lighblue ; font-style: italic;">Duplicates  </span>

# %%
train = train.drop_duplicates()
test  = test.drop_duplicates()
print(f'{yb_}\nDuplicates has been Removed.{end_}')
# Out:
# Duplicates has been Removed.

# %% [markdown]
# <span style="font-family:cursive; font-size:36px; padding:8px 16px; border-radius:98px 40px 160px 8px; border-left:8px solid lightblue ; font-weight:bold;"> 7 <span style="color:lighblue ; font-style: italic;"> Labels </span>

# %%
label = train['label']
train = train.drop(['label'],axis=1)
test_label = test['label']
test = test.drop(['label'],axis=1)

# %% [markdown]
# <span style="font-family:cursive; font-size:36px; padding:8px 16px; border-radius:98px 40px 160px 8px; border-left:8px solid lightblue ; font-weight:bold;"> 8 <span style="color:lighblue ; font-style: italic;"> Normalization </span>

# %%
train = train /255
test  = test /255
# numpy arrays 
train = np.array(train)
test  = np.array(test)
# 28 by 28 
train = train.reshape(train.shape[0],28,28,1)
test  = test.reshape(test.shape[0],28,28,1)

print(f'{yb_}\n Now Data is Normalized.{end_}')
# Out:
#  Now Data is Normalized.

# %% [markdown]
# # <p style="background-color: black; color: lightblue; padding-right: 100vw; text-align: center; font-family:newtimeroman;padding: 10px; border-radius: 15px 50px; border: 2px solid lightblue;font-size: 33px; text-shadow: 2px 2px 5px rgba(4, 5, 0, 0.5); box-shadow: 5px 5px 15px white;"><span style="color: #e67e22; margin: 0 10px; animation: flicker 1s infinite;">🍂</span> Visulization   🍃

# %% [markdown]
# > **Let's check the distribution of labels in the dataset.**my

# %%
labels = train["label"].value_counts().sort_index(ascending=True)
fig = px.bar(
    x=labels.index,
    y=labels.values,
    title="Labels and their images",
    labels={"x": "Label", "y": "Number of Images"},
    text=labels.values,
    color_discrete_sequence=["#ADD8E6"],  
)

fig.update_layout(
    title_x=0.5,
    title_font_color="#fff",
    title_font_size=20,
    paper_bgcolor="#000000",  
    font_color="#fff",
    plot_bgcolor="#000000", 
    xaxis=dict(
        tickmode='linear',
        ticktext=labels.index
    ))

fig.update_yaxes(showgrid=False)
fig.update_traces(textfont_color='purple') 
fig.show()
# Out:
# <div>                            <div id="7d2c96db-3c1b-4b46-89f3-fb3c7abdf2e7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7d2c96db-3c1b-4b46-89f3-fb3c7abdf2e7")) {                    Plotly.newPlot(                        "7d2c96db-3c1b-4b46-89f3-fb3c7abdf2e7",                        [{"alignmentgroup":"True","hovertemplate":"Label=%{x}\u003cbr\u003eNumber of Images=%{y}\u003cbr\u003etext=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#ADD8E6","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[1126.0,1010.0,1144.0,1196.0,957.0,1204.0,1090.0,1013.0,1162.0,1114.0,1241.0,1055.0,1151.0,1196.0,1088.0,1279.0,1294.0,1199.0,1186.0,1161.0,1082.0,1225.0,1164.0,1118.0],"te
# ...

# %% [markdown]
# > **As I can see, the dataset is quite balanced, so we are good to go.**

# %% [markdown]
# <span style="font-family:cursive; font-size:36px; padding:8px 16px; border-radius:98px 40px 160px 8px; border-left:8px solid lightblue ; font-weight:bold;">  <span style="color:lighblue ; font-style: italic;"> Images from Test & Train Data </span>

# %%
image_x = random.randint(0,len(test))
plt.imshow(np.reshape(train[image_x],(28,28)))
plt.title('Train Image')
plt.show()
plt.imshow(np.reshape(test[image_x],(28,28)))
plt.title('Test Image')
plt.show()

# %% [markdown]
# # <p style="background-color: black; color: lightblue; padding-right: 100vw; text-align: center; font-family:newtimeroman;padding: 10px; border-radius: 15px 50px; border: 2px solid lightblue;font-size: 33px; text-shadow: 2px 2px 5px rgba(4, 5, 0, 0.5); box-shadow: 5px 5px 15px white;"><span style="color: #e67e22; margin: 0 10px; animation: flicker 1s infinite;">🍂</span> Modelling || CNN Building  🍃

# %% [markdown]
# ![_a359da0a-401e-416f-b561-614a22bf450b.jpeg](attachment:876364de-8a81-4f85-adf5-e0857d21154f.jpeg)

# %% [markdown]
# <span style="font-family:cursive; font-size:36px; padding:8px 16px; border-radius:98px 40px 160px 8px; border-left:8px solid lightblue ; font-weight:bold;">  <span style="color:lighblue ; font-style: italic;">CNN Architecture </span>

# %%
model = models.Sequential()
model.add(layers.Conv2D(64,(3,3),padding ='Same',activation = 'relu',input_shape=(28,28,1)))
model.add(Dropout(0.1))
model.add(BatchNormalization())
model.add(layers.MaxPooling2D(2,2))
model.add(Dropout(0.3))
model.add(layers.Conv2D(128,(3,3),padding ='same',activation='relu'))
model.add(BatchNormalization())
model.add(layers.MaxPooling2D(2,2))
model.add(Dropout(0.3))
model.add(layers.Conv2D(128,(3,3),padding ='same',activation='relu'))
model.add(BatchNormalization())
model.add(layers.MaxPooling2D(2,2))

# %% [markdown]
# <span style="font-family:cursive; font-size:36px; padding:8px 16px; border-radius:98px 40px 160px 8px; border-left:8px solid lightblue ; font-weight:bold;">  <span style="color:lighblue ; font-style: italic;">Summary  </span>

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 28, 28, 64)     │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 28, 28, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 28, 28, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 14, 14, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
#adding some layers 
model.add(layers.Flatten())
model.add(layers.Dense(128, activation='relu'))
model.add(Dropout(0.2))
model.add(layers.Dense(25, activation ='softmax'))

# %% [markdown]
# <span style="font-family:cursive; font-size:36px; padding:8px 16px; border-radius:98px 40px 160px 8px; border-left:8px solid lightblue ; font-weight:bold;">  <span style="color:lighblue ; font-style: italic;">Complie </span>

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),metrics=['accuracy'])

# %% [markdown]
# <span style="font-family:cursive; font-size:36px; padding:8px 16px; border-radius:98px 40px 160px 8px; border-left:8px solid lightblue ; font-weight:bold;">  <span style="color:lighblue ; font-style: italic;">Training  </span>

# %%
history = model.fit(train,label,epochs=10,validation_data=(test,test_label))
# Out:
# Epoch 1/10
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 82s 92ms/step - accuracy: 0.6248 - loss: 1.2987 - val_accuracy: 0.9419 - val_loss: 0.1890
# Epoch 2/10
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 80s 90ms/step - accuracy: 0.9842 - loss: 0.0480 - val_accuracy: 0.9586 - val_loss: 0.1284
# Epoch 3/10
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 83s 91ms/step - accuracy: 0.9899 - loss: 0.0294 - val_accuracy: 0.9385 - val_loss: 0.2082
# Epoch 4/10
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 77s 90ms/step - accuracy: 0.9898 - loss: 0.0285 - val_accuracy: 0.9437 - val_loss: 0.1737
# Epoch 5/10
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 78s 90ms/step - accuracy: 0.9939 - loss: 0.0172 - val_accuracy: 0.9438 - val_loss: 0.2481
# Epoch 6/10
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 77s 90ms/step - accuracy: 0.9915 - loss: 0.0271 - val_accuracy: 0.9593 - val_loss: 0.1867
# Epoch 7/10
# 858/858 ━━━━━━━━━━━━━━━━━━━━ 77s 90ms/step - accuracy: 0.9918 - loss: 0.0265 - val_accuracy: 0.8578 - val_loss: 0.7771
# Epoch 8/10
# ...

# %% [markdown]
# <span style="font-family:cursive; font-size:36px; padding:8px 16px; border-radius:98px 40px 160px 8px; border-left:8px solid lightblue ; font-weight:bold;">  <span style="color:lighblue ; font-style: italic;">Evaluation</span>

# %%
model.evaluate(test, test_label)
# Out:
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - accuracy: 0.8597 - loss: 0.9951
# [0.9281272888183594, 0.8669826984405518]

# %% [markdown]
# > ###  **86% Acc with Simple CNN is good we can inc with use of Transformers or  adding some more layers**

# %%
#predection
predictions = model.predict(test)
predictions = np.argmax(predictions, axis = 1)
predictions[5]
# Out:
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step
# 21

# %%
plt.imshow(np.reshape(test[5],(28,28)))
plt.title('Test Image')
plt.show()

# %% [markdown]
# <span style="font-family:cursive; font-size:36px; padding:8px 16px; border-radius:98px 40px 160px 8px; border-left:8px solid lightblue ; font-weight:bold;">  <span style="color:lighblue ; font-style: italic;">Accuracy Plot </span>

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

test_loss, test_acc = model.evaluate(test,  test_label, verbose=2)
# Out:
# 225/225 - 4s - 19ms/step - accuracy: 0.8670 - loss: 0.9281

# %% [markdown]
# ![_7d1f9c18-096f-4108-abab-7c4c9727357e.jpeg](attachment:85c10293-4719-42ad-9071-677985b90617.jpeg)
